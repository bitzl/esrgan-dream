# %%
import cv2
import IPython

def imgshow(img):
    _,ret = cv2.imencode('.jpg', img) 
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %%
import numpy as np

rng = np.random.Generator(np.random.PCG64(0))

rng.integers(255, size=(16, 16, 3), dtype=np.uint8)
# Out:
# array([[[ 94, 129, 193],
#         [216, 206, 234],
#         [ 14, 162,  32],
#         [214, 216, 129],
#         [247, 188,  15],
#         [ 68, 183, 231],
#         [204,  77, 168],
#         [ 60, 124,   9],
#         [ 28, 239,  65],
#         [ 18, 181,  38],
#         [ 58,   3,  58],
#         [ 80, 221,  43],
#         [119, 121,  49],
#         [207,  77,  27],
#         [ 63, 165, 120],
#         [ 88, 169, 232]],
#
#        [[126, 177, 236],
#         [127, 112, 122],
#         [ 75, 154,  68],
#         [153, 129, 247],
#         [ 94,  72, 191],
#         [185, 190, 126],
#         [219, 160, 230],
#         [  0,  42, 138],
#         [236, 190,  85],
#         [142,   6, 231],
#         [ 95, 238,  75],
#         [ 54,  70,  76],
#         [198, 218, 207],
#         [175, 143, 189],
#         [170, 103, 119],
#         [178, 239, 244]],
#
#        [[229,  99, 190],
#         [215, 125, 218],
#         [ 30, 148, 230],
#         [140, 114,  15],
# ...
